# %% [markdown]
# # Modelo multinível

# %% [markdown]
# [Fonte: storopoli](https://storopoli.github.io/Bayesian-Julia/pages/11_multilevel_models/)

# %%
# Pacotes necessários
import Pkg
#Pkg.add("StatsPlots")
#Pkg.add("Distributions")
#Pkg.add("LaTeXStrings")
#Pkg.add("DataFrames")
#Pkg.add("CSV")
#Pkg.add("Plots")

# %%
# Carregar pacotes
using StatsPlots, Distributions, LaTeXStrings, DataFrames, CSV

# %%
using DataFrames, CSV, HTTP

url = "https://raw.githubusercontent.com/storopoli/Bayesian-Julia/master/datasets/cheese.csv"
cheese = CSV.read(HTTP.get(url).body, DataFrame)
println(cheese)
describe(cheese)
# Out:
# 160×4 DataFrame
#  Row │ cheese   rater  background  y
#      │ String1  Int64  String7     Int64
# ─────┼───────────────────────────────────
#    1 │ A            1  rural          67
#    2 │ A            1  rural          66
#    3 │ B            1  rural          51
#    4 │ B            1  rural          53
#    5 │ C            1  rural          75
#    6 │ C            1  rural          70
#    7 │ D            1  rural          68
#    8 │ D            1  rural          66
#    9 │ A            2  rural          76
#   10 │ A            2  rural          76
#   11 │ B            2  rural          56
#   12 │ B            2  rural          65
#   13 │ C            2  rural          82
#   14 │ C            2  rural          82
#   15 │ D            2  rural          81
#   16 │ D            2  rural          77
#   17 │ A            3  rural          80
#   18 │ A            3  rural          84
#   19 │ B            3  rural          71
#   20 │ B            3  rural          67
#   21 │ C            3  rural          82
#   22 │ C            3  rural          82
#   23 │ D            3  rural          71
#   24 │ D            3  rural          70
#   25 │ A            4  rural          79
#   26 │ A            4  rural          83
#   27 │ B            4  rural          63
#   28 │ B            4  rural          60
#   29 │ C            4  rural          80
#   30 │ C            4  rural          83
#   31 │ D            4  rural          66
#   32 │ D            4  rural          71
#   33 │ A            5  rural          74
#   34 │ A            5  rural          72
#   35 │ B            5  rural          55
#   36 │ B            5  rural          58
#   37 │ C            5  rural          76
#   38 │ C            5  rural          79
#   39 │ D            5  rural          75
#   40 │ D            5  rural          74
#   41 │ A            6  rural          66
#   42 │ A            6  rural          71
#   43 │ B            6  rural          49
#   44 │ B            6  rural          49
#   45 │ C            6  rural          72
#   46 │ C            6  rural          70
#   47 │ D            6  rural          65
#   48 │ D            6  rural          65
#   49 │ A            7  rural          63
#   50 │ A            7  rural          68
#   51 │ B            7  rural          38
#   52 │ B            7  rural          33
#   53 │ C            7  rural          72
#   54 │ C            7  rural          71
#   55 │ D            7  rural          70
#   56 │ D            7  rural          72
#   57 │ A            8  rural          67
#   58 │ A            8  rural          60
#   59 │ B            8  rural          56
#   60 │ B            8  rural          48
#   61 │ C            8  rural          72
#   62 │ C            8  rural          70
#   63 │ D            8  rural          67
#   64 │ D            8  rural          69
#   65 │ A            9  rural          59
#   66 │ A            9  rural          65
#   67 │ B            9  rural          41
#   68 │ B            9  rural          48
#   69 │ C            9  rural          61
#   70 │ C            9  rural          70
#   71 │ D            9  rural          57
#   72 │ D            9  rural          59
#   73 │ A           10  rural          72
#   74 │ A           10  rural          64
#   75 │ B           10  rural          55
#   76 │ B           10  rural          57
#   77 │ C           10  rural          78
#   78 │ C           10  rural          78
#   79 │ D           10  rural          72
#   80 │ D           10  rural          67
#   81 │ A            1  urban          67
#   82 │ A            1  urban          64
#   83 │ B            1  urban          44
#   84 │ B            1  urban          54
#   85 │ C            1  urban          75
#   86 │ C            1  urban          83
#   87 │ D            1  urban          64
#   88 │ D            1  urban          60
#   89 │ A            2  urban          83
#   90 │ A            2  urban          85
#   91 │ B            2  urban          60
#   92 │ B            2  urban          63
#   93 │ C            2  urban          91
#   94 │ C            2  urban          90
#   95 │ D            2  urban          67
#   96 │ D            2  urban          69
#   97 │ A            3  urban          74
#   98 │ A            3  urban          75
#   99 │ B            3  urban          58
#  100 │ B            3  urban          54
#  101 │ C            3  urban          77
#  102 │ C            3  urban          80
#  103 │ D            3  urban          64
#  104 │ D            3  urban          66
#  105 │ A            4  urban          81
#  106 │ A            4  urban          84
#  107 │ B            4  urban          58
#  108 │ B            4  urban          62
#  109 │ C            4  urban          86
#  110 │ C            4  urban          90
#  111 │ D            4  urban          71
#  112 │ D            4  urban          67
#  113 │ A            5  urban          83
#  114 │ A            5  urban          79
#  115 │ B            5  urban          54
#  116 │ B            5  urban          57
#  117 │ C            5  urban          91
#  118 │ C            5  urban          82
#  119 │ D            5  urban          78
#  120 │ D            5  urban          84
#  121 │ A            6  urban          84
#  122 │ A            6  urban          82
#  123 │ B            6  urban          65
#  124 │ B            6  urban          61
#  125 │ C            6  urban          80
#  126 │ C            6  urban          87
#  127 │ D            6  urban          78
#  128 │ D            6  urban          84
#  129 │ A            7  urban          89
#  130 │ A            7  urban          84
#  131 │ B            7  urban          70
#  132 │ B            7  urban          76
#  133 │ C            7  urban          79
#  134 │ C            7  urban          89
#  135 │ D            7  urban          89
#  136 │ D            7  urban          91
#  137 │ A            8  urban          80
#  138 │ A            8  urban          80
#  139 │ B            8  urban          62
#  140 │ B            8  urban          56
#  141 │ C            8  urban          85
#  142 │ C            8  urban          86
#  143 │ D            8  urban          77
#  144 │ D            8  urban          79
#  145 │ A            9  urban          74
#  146 │ A            9  urban          73
#  147 │ B            9  urban          56
#  148 │ B            9  urban          61
#  149 │ C            9  urban          78
#  150 │ C            9  urban          79
#  151 │ D            9  urban          77
#  152 │ D            9  urban          82
#  153 │ A           10  urban          77
#  154 │ A           10  urban          82
#  155 │ B           10  urban          64
#  156 │ B           10  urban          57
#  157 │ C           10  urban          86
#  158 │ C           10  urban          86
#  159 │ D           10  urban          81
#  160 │ D           10  urban          83
# 4×7 DataFrame
#  Row │ variable    mean     min    median  max    nmissing  eltype
#      │ Symbol      Union…   Any    Union…  Any    Int64     DataType
# ─────┼───────────────────────────────────────────────────────────────
#    1 │ cheese               A              D             0  String1
#    2 │ rater       5.5      1      5.5     10            0  Int64
#    3 │ background           rural          urban         0  String7
#    4 │ y           70.8438  33     71.5    91            0  Int64

# %%
for c in unique(cheese[:, :cheese])
    cheese[:, "cheese_$c"] = ifelse.(cheese[:, :cheese] .== c, 1, 0)
end

cheese[:, :background_int] = map(cheese[:, :background]) do b
    b == "rural" ? 1 :
    b == "urban" ? 2 : missing
end

first(cheese, 5)
# Out:
# 5×9 DataFrame
#  Row │ cheese   rater  background  y      cheese_A  cheese_B  cheese_C  cheese ⋯
#      │ String1  Int64  String7     Int64  Int64     Int64     Int64     Int64  ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ A            1  rural          67         1         0         0         ⋯
#    2 │ A            1  rural          66         1         0         0
#    3 │ B            1  rural          51         0         1         0
#    4 │ B            1  rural          53         0         1         0
#    5 │ C            1  rural          75         0         0         1         ⋯
#                                                                2 columns omitted

# %%
X = Matrix(select(cheese, Between(:cheese_A, :cheese_D)));
y = cheese[:, :y];
idx = cheese[:, :background_int];

# %% [markdown]
# ## Modelos

# %%
# Instalar pacotes necessários
#Pkg.add("Turing")
#Pkg.add("StatsBase")

# %%
using Turing
using LinearAlgebra: I
using Statistics: mean, std
using Random: seed!
seed!(123)
# Out:
# Random.TaskLocalRNG()

# %% [markdown]
# ### 1 - Modelo de interceptação aleatória

# %%
# varying_intercept
@model function varying_intercept(X, idx, y; n_gr=length(unique(idx)), predictors=size(X, 2))
    #priors
    α ~ Normal(mean(y), 2.5 * std(y))       # population-level intercept
    β ~ filldist(Normal(0, 2), predictors)  # population-level coefficients
    σ ~ Exponential(1 / std(y))             # residual SD
    #prior for variance of random intercepts
    #usually requires thoughtful specification
    τ ~ truncated(Cauchy(0, 2); lower=0)    # group-level SDs intercepts
    αⱼ ~ filldist(Normal(0, τ), n_gr)       # group-level intercepts

    #likelihood
    ŷ = α .+ X * β .+ αⱼ[idx]
    y ~ MvNormal(ŷ, σ^2 * I)
end;

# %%
# varying_intercept
model_intercept = varying_intercept(X, idx, y)
chain_intercept = sample(model_intercept, NUTS(), MCMCThreads(), 1_000, 4)
summarystats(chain_intercept) |> DataFrame |> println
# Out:
# ┌ Warning: Only a single thread available: MCMC chains are not sampled in parallel
# └ @ AbstractMCMC C:\Users\99836932\.julia\packages\AbstractMCMC\fnRmh\src\sample.jl:291
# ┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC C:\Users\99836932\.julia\packages\AdvancedHMC\iWHPQ\src\hamiltonian.jl:47
# ┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC C:\Users\99836932\.julia\packages\AdvancedHMC\iWHPQ\src\hamiltonian.jl:47
# ┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC C:\Users\99836932\.julia\packages\AdvancedHMC\iWHPQ\src\hamiltonian.jl:47
# ┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC C:\Users\99836932\.julia\packages\AdvancedHMC\iWHPQ\src\hamiltonian.jl:47
# ┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC C:\Users\99836932\.julia\packages\AdvancedHMC\iWHPQ\src\hamiltonian.jl:47
# ┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC C:\Users\99836932\.julia\packages\AdvancedHMC\iWHPQ\src\hamiltonian.jl:47
# ┌ Info: Found initial step size
# │   ϵ = 0.000390625
# └ @ Turing.Inference C:\Users\99836932\.julia\packages\Turing\szPqN\src\inference\hmc.jl:191
# ┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC C:\Users\99836932\.julia\packages\AdvancedHMC\iWHPQ\src\hamiltonian.jl:47
# ┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC C:\Users\99836932\.julia\packages\AdvancedHMC\iWHPQ\src\hamiltonian.jl:47
# ┌ Info: Found initial step size
# │   ϵ = 0.003125
# └ @ Turing.Inference C:\Users\99836932\.julia\packages\Turing\szPqN\src\inference\hmc.jl:191
# ┌ Info: Found initial step size
# │   ϵ = 0.0125
# └ @ Turing.Inference C:\Users\99836932\.julia\packages\Turing\szPqN\src\inference\hmc.jl:191
# ┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC C:\Users\99836932\.julia\packages\AdvancedHMC\iWHPQ\src\hamiltonian.jl:47
# Sampling (1 threads):  50%|███████████████              |  ETA: 0:00:04┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC C:\Users\99836932\.julia\packages\AdvancedHMC\iWHPQ\src\hamiltonian.jl:47
# ┌ Info: Found initial step size
# │   ϵ = 0.003125
# └ @ Turing.Inference C:\Users\99836932\.julia\packages\Turing\szPqN\src\inference\hmc.jl:191
# Sampling (1 threads): 100%|█████████████████████████████| Time: 0:00:08
# 9×8 DataFrame
#  Row │ parameters  mean       std       naive_se    mcse        ess       rhat      ess_per_sec
#      │ Symbol      Float64    Float64   Float64     Float64     Float64   Float64   Float64
# ─────┼──────────────────────────────────────────────────────────────────────────────────────────
#    1 │ α            70.8578   6.05178   0.0956871   0.23822      651.344  1.00389       23.3031
#    2 │ β[1]          3.20605  1.26977   0.0200769   0.0305339   2024.44   0.999996      72.4281
#    3 │ β[2]        -11.6263   1.26302   0.0199701   0.0304593   2025.53   1.0004        72.4672
#    4 │ β[3]          7.1691   1.29857   0.0205323   0.0328251   2024.68   1.00013       72.4367
#    5 │ β[4]          1.21296  1.25761   0.0198845   0.0317193   2159.03   1.00003       77.2434
#    6 │ σ             6.00355  0.278311  0.00440048  0.00469695  3222.51   0.999358     115.291
#    7 │ τ             6.84391  8.48557   0.134169    0.249498     824.663  1.003         29.5039
#    8 │ αⱼ[1]        -3.60016  5.95175   0.0941055   0.234061     647.513  1.00431       23.166
#    9 │ αⱼ[2]         3.57237  5.93688   0.0938704   0.232261     629.291  1.00448       22.5141

# %% [markdown]
# ### 2 - Modelo de inclinação aleatória

# %%
# varying_slope
@model function varying_slope(X, idx, y; n_gr=length(unique(idx)), predictors=size(X, 2))
    #priors
    α ~ Normal(mean(y), 2.5 * std(y))                    # population-level intercept
    σ ~ Exponential(1 / std(y))                          # residual SD
    #prior for variance of random slopes
    #usually requires thoughtful specification
    τ ~ filldist(truncated(Cauchy(0, 2); lower=0), n_gr) # group-level slopes SDs
    βⱼ ~ filldist(Normal(0, 1), predictors, n_gr)        # group-level standard normal slopes

    #likelihood
    ŷ = α .+ X * βⱼ * τ
    y ~ MvNormal(ŷ, σ^2 * I)
end;

# %%
model_slope = varying_slope(X, idx, y)
chain_slope = sample(model_slope, NUTS(), MCMCThreads(), 1_000, 4)
summarystats(chain_slope) |> DataFrame |> println
# Out:
# ┌ Warning: Only a single thread available: MCMC chains are not sampled in parallel
# └ @ AbstractMCMC C:\Users\99836932\.julia\packages\AbstractMCMC\fnRmh\src\sample.jl:291
# ┌ Info: Found initial step size
# │   ϵ = 0.0125
# └ @ Turing.Inference C:\Users\99836932\.julia\packages\Turing\szPqN\src\inference\hmc.jl:191
# ┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC C:\Users\99836932\.julia\packages\AdvancedHMC\iWHPQ\src\hamiltonian.jl:47
# ┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC C:\Users\99836932\.julia\packages\AdvancedHMC\iWHPQ\src\hamiltonian.jl:47
# ┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC C:\Users\99836932\.julia\packages\AdvancedHMC\iWHPQ\src\hamiltonian.jl:47
# ┌ Info: Found initial step size
# │   ϵ = 0.0015625
# └ @ Turing.Inference C:\Users\99836932\.julia\packages\Turing\szPqN\src\inference\hmc.jl:191
# ┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC C:\Users\99836932\.julia\packages\AdvancedHMC\iWHPQ\src\hamiltonian.jl:47
# ┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC C:\Users\99836932\.julia\packages\AdvancedHMC\iWHPQ\src\hamiltonian.jl:47
# Sampling (1 threads):  50%|███████████████              |  ETA: 0:00:07┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC C:\Users\99836932\.julia\packages\AdvancedHMC\iWHPQ\src\hamiltonian.jl:47
# ┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC C:\Users\99836932\.julia\packages\AdvancedHMC\iWHPQ\src\hamiltonian.jl:47
# ┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC C:\Users\99836932\.julia\packages\AdvancedHMC\iWHPQ\src\hamiltonian.jl:47
# ┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC C:\Users\99836932\.julia\packages\AdvancedHMC\iWHPQ\src\hamiltonian.jl:47
# ┌ Info: Found initial step size
# │   ϵ = 0.0001953125
# └ @ Turing.Inference C:\Users\99836932\.julia\packages\Turing\szPqN\src\inference\hmc.jl:191
# ┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC C:\Users\99836932\.julia\packages\AdvancedHMC\iWHPQ\src\hamiltonian.jl:47
# ┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC C:\Users\99836932\.julia\packages\AdvancedHMC\iWHPQ\src\hamiltonian.jl:47
# Sampling (1 threads):  75%|██████████████████████       |  ETA: 0:00:04┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC C:\Users\99836932\.julia\packages\AdvancedHMC\iWHPQ\src\hamiltonian.jl:47
# ┌ Info: Found initial step size
# │   ϵ = 0.0015625
# └ @ Turing.Inference C:\Users\99836932\.julia\packages\Turing\szPqN\src\inference\hmc.jl:191
# Sampling (1 threads): 100%|█████████████████████████████| Time: 0:00:17
# 12×8 DataFrame
#  Row │ parameters  mean        std       naive_se    mcse        ess       rhat      ess_per_sec
#      │ Symbol      Float64     Float64   Float64     Float64     Float64   Float64   Float64
# ─────┼───────────────────────────────────────────────────────────────────────────────────────────
#    1 │ α           70.9703     5.1184    0.080929    0.139945    1195.76   1.00102       35.6061
#    2 │ σ            6.5362     0.280443  0.00443419  0.00524903  2798.96   1.00061       83.3445
#    3 │ τ[1]         6.25541    5.41333   0.0855922   0.214566     619.93   1.00211       18.4596
#    4 │ τ[2]         6.27494    5.2265    0.0826383   0.202745     616.858  1.00356       18.3682
#    5 │ βⱼ[1,1]      0.235394   0.790277  0.0124954   0.0189687   1634.14   0.999829      48.6598
#    6 │ βⱼ[2,1]     -0.89466    1.03596   0.01638     0.0324722   1074.36   1.00128       31.9911
#    7 │ βⱼ[3,1]      0.554768   0.860399  0.0136041   0.0239711   1303.5    1.002         38.8144
#    8 │ βⱼ[4,1]      0.0701017  0.780211  0.0123362   0.0174055   1986.36   1.00136       59.1479
#    9 │ βⱼ[1,2]      0.242824   0.792832  0.0125358   0.0210889   1620.89   1.00237       48.2651
#   10 │ βⱼ[2,2]     -0.940774   1.03365   0.0163435   0.0361469    864.114  1.00213       25.7307
#   11 │ βⱼ[3,2]      0.545601   0.887381  0.0140307   0.0240918   1312.84   1.00218       39.0923
#   12 │ βⱼ[4,2]      0.109887   0.766641  0.0121217   0.0153795   2018.64   1.00166       60.109

# %% [markdown]
# # 3 - Modelo de inclinação de interceptação aleatória

# %%
# varying_intercept_slope
@model function varying_intercept_slope(X, idx, y; n_gr=length(unique(idx)), predictors=size(X, 2))
    #priors
    α ~ Normal(mean(y), 2.5 * std(y))                     # population-level intercept
    σ ~ Exponential(1 / std(y))                           # residual SD
    #prior for variance of random intercepts and slopes
    #usually requires thoughtful specification
    τₐ ~ truncated(Cauchy(0, 2); lower=0)                 # group-level SDs intercepts
    τᵦ ~ filldist(truncated(Cauchy(0, 2); lower=0), n_gr) # group-level slopes SDs
    αⱼ ~ filldist(Normal(0, τₐ), n_gr)                    # group-level intercepts
    βⱼ ~ filldist(Normal(0, 1), predictors, n_gr)         # group-level standard normal slopes

    #likelihood
    ŷ = α .+ αⱼ[idx] .+ X * βⱼ * τᵦ
    y ~ MvNormal(ŷ, σ^2 * I)
end;

# %%
model_intercept_slope = varying_intercept_slope(X, idx, y)
chain_intercept_slope = sample(model_intercept_slope, NUTS(), MCMCThreads(), 1_000, 4)
summarystats(chain_intercept_slope) |> DataFrame |> println
# Out:
# ┌ Warning: Only a single thread available: MCMC chains are not sampled in parallel
# └ @ AbstractMCMC C:\Users\99836932\.julia\packages\AbstractMCMC\fnRmh\src\sample.jl:291
# ┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC C:\Users\99836932\.julia\packages\AdvancedHMC\iWHPQ\src\hamiltonian.jl:47
# ┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC C:\Users\99836932\.julia\packages\AdvancedHMC\iWHPQ\src\hamiltonian.jl:47
# ┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC C:\Users\99836932\.julia\packages\AdvancedHMC\iWHPQ\src\hamiltonian.jl:47
# ┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC C:\Users\99836932\.julia\packages\AdvancedHMC\iWHPQ\src\hamiltonian.jl:47
# ┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC C:\Users\99836932\.julia\packages\AdvancedHMC\iWHPQ\src\hamiltonian.jl:47
# ┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC C:\Users\99836932\.julia\packages\AdvancedHMC\iWHPQ\src\hamiltonian.jl:47
# ┌ Info: Found initial step size
# │   ϵ = 0.0001953125
# └ @ Turing.Inference C:\Users\99836932\.julia\packages\Turing\szPqN\src\inference\hmc.jl:191
# ┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC C:\Users\99836932\.julia\packages\AdvancedHMC\iWHPQ\src\hamiltonian.jl:47
# ┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC C:\Users\99836932\.julia\packages\AdvancedHMC\iWHPQ\src\hamiltonian.jl:47
# ┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC C:\Users\99836932\.julia\packages\AdvancedHMC\iWHPQ\src\hamiltonian.jl:47
# ┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC C:\Users\99836932\.julia\packages\AdvancedHMC\iWHPQ\src\hamiltonian.jl:47
# ┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC C:\Users\99836932\.julia\packages\AdvancedHMC\iWHPQ\src\hamiltonian.jl:47
# ┌ Info: Found initial step size
# │   ϵ = 0.000390625
# └ @ Turing.Inference C:\Users\99836932\.julia\packages\Turing\szPqN\src\inference\hmc.jl:191
# ┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC C:\Users\99836932\.julia\packages\AdvancedHMC\iWHPQ\src\hamiltonian.jl:47
# ┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC C:\Users\99836932\.julia\packages\AdvancedHMC\iWHPQ\src\hamiltonian.jl:47
# Sampling (1 threads):  50%|███████████████              |  ETA: 0:00:10┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC C:\Users\99836932\.julia\packages\AdvancedHMC\iWHPQ\src\hamiltonian.jl:47
# ┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC C:\Users\99836932\.julia\packages\AdvancedHMC\iWHPQ\src\hamiltonian.jl:47
# ┌ Info: Found initial step size
# │   ϵ = 0.0015625
# └ @ Turing.Inference C:\Users\99836932\.julia\packages\Turing\szPqN\src\inference\hmc.jl:191
# ┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC C:\Users\99836932\.julia\packages\AdvancedHMC\iWHPQ\src\hamiltonian.jl:47
# ┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC C:\Users\99836932\.julia\packages\AdvancedHMC\iWHPQ\src\hamiltonian.jl:47
# Sampling (1 threads):  75%|██████████████████████       |  ETA: 0:00:06┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC C:\Users\99836932\.julia\packages\AdvancedHMC\iWHPQ\src\hamiltonian.jl:47
# ┌ Info: Found initial step size
# │   ϵ = 0.0015625
# └ @ Turing.Inference C:\Users\99836932\.julia\packages\Turing\szPqN\src\inference\hmc.jl:191
# Sampling (1 threads): 100%|█████████████████████████████| Time: 0:00:29
# 15×8 DataFrame
#  Row │ parameters  mean        std       naive_se    mcse        ess       rhat      ess_per_sec
#      │ Symbol      Float64     Float64   Float64     Float64     Float64   Float64   Float64
# ─────┼───────────────────────────────────────────────────────────────────────────────────────────
#    1 │ α           70.7216     6.6562    0.105244    0.181309     977.525  1.00415       19.0439
#    2 │ σ            5.8707     0.264046  0.00417494  0.00452719  3197.4    0.999426      62.291
#    3 │ τₐ           6.13431    5.6476    0.0892964   0.169549    1028.77   1.00173       20.0424
#    4 │ τᵦ[1]        6.10334    5.25169   0.0830364   0.223342     559.866  1.01507       10.9072
#    5 │ τᵦ[2]        6.11804    4.9705    0.0785904   0.194656     596.697  1.01336       11.6247
#    6 │ αⱼ[1]       -3.4754     4.87065   0.0770118   0.167706     715.271  1.00473       13.9348
#    7 │ αⱼ[2]        3.71458    4.88746   0.0772775   0.167296     725.576  1.0045        14.1355
#    8 │ βⱼ[1,1]      0.200116   0.812417  0.0128454   0.020781    1757.06   1.00365       34.2307
#    9 │ βⱼ[2,1]     -0.885444   1.04104   0.0164603   0.034224     913.48   1.01189       17.7962
#   10 │ βⱼ[3,1]      0.536807   0.904774  0.0143057   0.0270473   1437.97   1.00441       28.0142
#   11 │ βⱼ[4,1]      0.0735369  0.800008  0.0126492   0.0172372   2326.59   1.00127       45.326
#   12 │ βⱼ[1,2]      0.26716    0.787086  0.0124449   0.0169315   1625.12   1.00173       31.6603
#   13 │ βⱼ[2,2]     -0.919201   1.04464   0.0165172   0.0367509    729.885  1.00918       14.2195
#   14 │ βⱼ[3,2]      0.579487   0.900078  0.0142315   0.0222768   1315.39   1.00548       25.6262
#   15 │ βⱼ[4,2]      0.120118   0.812698  0.0128499   0.0178323   1996.74   1.00061       38.9
